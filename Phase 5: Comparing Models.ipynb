# %%
# Phase 5: Comparing Regressors

# %% [markdown]
# ## 1. Import libraries

# %%
! pip install lazypredict
# Out:
# Requirement already satisfied: lazypredict in ./.venv/lib/python3.12/site-packages (0.2.12)
# Requirement already satisfied: click in ./.venv/lib/python3.12/site-packages (from lazypredict) (8.1.7)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.12/site-packages (from lazypredict) (1.5.1)
# Requirement already satisfied: pandas in ./.venv/lib/python3.12/site-packages (from lazypredict) (2.2.2)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.12/site-packages (from lazypredict) (4.66.5)
# Requirement already satisfied: joblib in ./.venv/lib/python3.12/site-packages (from lazypredict) (1.4.2)
# Requirement already satisfied: lightgbm in ./.venv/lib/python3.12/site-packages (from lazypredict) (4.5.0)
# Requirement already satisfied: xgboost in ./.venv/lib/python3.12/site-packages (from lazypredict) (2.1.1)
# Requirement already satisfied: numpy>=1.17.0 in ./.venv/lib/python3.12/site-packages (from lightgbm->lazypredict) (2.0.0)
# Requirement already satisfied: scipy in ./.venv/lib/python3.12/site-packages (from lightgbm->lazypredict) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas->lazypredict) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas->lazypredict) (2024.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.12/site-packages (from scikit-learn->lazypredict) (3.5.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->lazypredict) (1.16.0)

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyRegressor

# %% [markdown]
# ## 2. Load the data set

# %%
df = pd.read_csv('RET_04_bioactivity_data_pIC50_pubchem_fp.csv')

# %%
X = df.drop('pIC50', axis =1)
Y = df.pIC50

# %% [markdown]
# ## 3. Data pre-processing

# %%
# Examine X dimension
X.shape
# Out:
# (896, 881)

# %%
# Remove the low variance features, because the features identified as low variance are essentially not changing (constant) and will not improve the regression model
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(0.8 * (1 - 0.8)))
X = selection.fit_transform(X)
X.shape
# Out:
# (896, 156)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ## 4. Compare ML algorithms

# %%
# Defines and builds the lazyclassifier
clf = LazyRegressor(verbose = 0, ignore_warnings = True, custom_metric= None)
train, test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
#  98%|█████████▊| 41/42 [00:06<00:00,  9.51it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000852 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 468
# [LightGBM] [Info] Number of data points in the train set: 716, number of used features: 156
# [LightGBM] [Info] Start training from score 6.492488
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 100%|██████████| 42/42 [00:07<00:00,  5.70it/s]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
train
# Out:
#                                                 Adjusted R-Squared  \
# Model
# NuSVR                                                        -4.49
# RandomForestRegressor                                        -4.59
# GammaRegressor                                               -4.75
# TweedieRegressor                                             -4.75
# KNeighborsRegressor                                          -4.80
# BayesianRidge                                                -4.82
# SVR                                                          -4.83
# ElasticNetCV                                                 -4.86
# PoissonRegressor                                             -4.90
# LassoCV                                                      -4.94
# LassoLarsCV                                                  -4.95
# BaggingRegressor                                             -4.96
# LassoLarsIC                                                  -5.09
# HistGradientBoostingRegressor                                -5.15
# OrthogonalMatchingPursuit                                    -5.24
# OrthogonalMatchingPursuitCV                                  -5.25
# AdaBoostRegressor                                            -5.25
# GradientBoostingRegressor                                    -5.28
# LGBMRegressor                                                -5.33
# LarsCV                                                       -5.44
# SGDRegressor                                                 -5.55
# RidgeCV                                                      -5.61
# XGBRegressor                                                 -6.17
# Ridge                                                        -6.42
# MLPRegressor                                                 -6.68
# HuberRegressor                                               -6.69
# LassoLars                                                    -6.79
# ElasticNet                                                   -6.79
# DummyRegressor                                               -6.79
# Lasso                                                        -6.79
# QuantileRegressor                                            -6.79
# LinearSVR                                                    -7.07
# ExtraTreesRegressor                                          -8.14
# ExtraTreeRegressor                                           -8.74
# DecisionTreeRegressor                                        -8.92
# PassiveAggressiveRegressor                                   -9.39
# GaussianProcessRegressor                                   -103.54
# KernelRidge                                                -147.89
# TransformedTargetRegressor             -31897904657923768844288.00
# LinearRegression                       -31897904657923768844288.00
# RANSACRegressor                     -15511889446600085642149888.00
# Lars                          -33788130306338377063153608425472.00
#
#                                                         R-Squared  \
# Model
# NuSVR                                                        0.29
# RandomForestRegressor                                        0.28
# GammaRegressor                                               0.26
# TweedieRegressor                                             0.26
# KNeighborsRegressor                                          0.25
# BayesianRidge                                                0.25
# SVR                                                          0.25
# ElasticNetCV                                                 0.25
# PoissonRegressor                                             0.24
# LassoCV                                                      0.24
# LassoLarsCV                                                  0.24
# BaggingRegressor                                             0.23
# LassoLarsIC                                                  0.22
# HistGradientBoostingRegressor                                0.21
# OrthogonalMatchingPursuit                                    0.20
# OrthogonalMatchingPursuitCV                                  0.20
# AdaBoostRegressor                                            0.20
# GradientBoostingRegressor                                    0.19
# LGBMRegressor                                                0.19
# LarsCV                                                       0.17
# SGDRegressor                                                 0.16
# RidgeCV                                                      0.15
# XGBRegressor                                                 0.08
# Ridge                                                        0.05
# MLPRegressor                                                 0.01
# HuberRegressor                                               0.01
# LassoLars                                                   -0.00
# ElasticNet                                                  -0.00
# DummyRegressor                                              -0.00
# Lasso                                                       -0.00
# QuantileRegressor                                           -0.00
# LinearSVR                                                   -0.04
# ExtraTreesRegressor                                         -0.17
# ExtraTreeRegressor                                          -0.25
# DecisionTreeRegressor                                       -0.28
# PassiveAggressiveRegressor                                  -0.33
# GaussianProcessRegressor                                   -12.43
# KernelRidge                                                -18.13
# TransformedTargetRegressor             -4098613447666182389760.00
# LinearRegression                       -4098613447666182389760.00
# RANSACRegressor                     -1993147805987720637972480.00
# Lars                          -4341491603607724206961096392704.00
#
#                                              RMSE  Time Taken
# Model
# NuSVR                                        1.26        0.03
# RandomForestRegressor                        1.27        0.54
# GammaRegressor                               1.29        0.01
# TweedieRegressor                             1.29        0.01
# KNeighborsRegressor                          1.29        0.01
# BayesianRidge                                1.30        0.01
# SVR                                          1.30        0.04
# ElasticNetCV                                 1.30        1.72
# PoissonRegressor                             1.30        0.01
# LassoCV                                      1.31        1.48
# LassoLarsCV                                  1.31        0.02
# BaggingRegressor                             1.31        0.07
# LassoLarsIC                                  1.32        0.02
# HistGradientBoostingRegressor                1.33        0.56
# OrthogonalMatchingPursuit                    1.34        0.01
# OrthogonalMatchingPursuitCV                  1.34        0.01
# AdaBoostRegressor                            1.34        0.10
# GradientBoostingRegressor                    1.34        0.22
# LGBMRegressor                                1.35        0.49
# LarsCV                                       1.36        0.09
# SGDRegressor                                 1.37        0.01
# RidgeCV                                      1.38        0.01
# XGBRegressor                                 1.44        0.22
# Ridge                                        1.46        0.01
# MLPRegressor                                 1.49        0.26
# HuberRegressor                               1.49        0.04
# LassoLars                                    1.50        0.01
# ElasticNet                                   1.50        0.01
# DummyRegressor                               1.50        0.00
# Lasso                                        1.50        0.01
# QuantileRegressor                            1.50        0.07
# LinearSVR                                    1.52        0.11
# ExtraTreesRegressor                          1.62        0.75
# ExtraTreeRegressor                           1.68        0.06
# DecisionTreeRegressor                        1.69        0.01
# PassiveAggressiveRegressor                   1.73        0.01
# GaussianProcessRegressor                     5.49        0.05
# KernelRidge                                  6.55        0.01
# TransformedTargetRegressor         95866393176.18        0.01
# LinearRegression                   95866393176.18        0.01
# RANSACRegressor                  2114061711578.00        0.22
# Lars                          3120091931525409.50        0.02

# %%
test
# Out:
#                                                 Adjusted R-Squared  \
# Model
# NuSVR                                                        -4.49
# RandomForestRegressor                                        -4.59
# GammaRegressor                                               -4.75
# TweedieRegressor                                             -4.75
# KNeighborsRegressor                                          -4.80
# BayesianRidge                                                -4.82
# SVR                                                          -4.83
# ElasticNetCV                                                 -4.86
# PoissonRegressor                                             -4.90
# LassoCV                                                      -4.94
# LassoLarsCV                                                  -4.95
# BaggingRegressor                                             -4.96
# LassoLarsIC                                                  -5.09
# HistGradientBoostingRegressor                                -5.15
# OrthogonalMatchingPursuit                                    -5.24
# OrthogonalMatchingPursuitCV                                  -5.25
# AdaBoostRegressor                                            -5.25
# GradientBoostingRegressor                                    -5.28
# LGBMRegressor                                                -5.33
# LarsCV                                                       -5.44
# SGDRegressor                                                 -5.55
# RidgeCV                                                      -5.61
# XGBRegressor                                                 -6.17
# Ridge                                                        -6.42
# MLPRegressor                                                 -6.68
# HuberRegressor                                               -6.69
# LassoLars                                                    -6.79
# ElasticNet                                                   -6.79
# DummyRegressor                                               -6.79
# Lasso                                                        -6.79
# QuantileRegressor                                            -6.79
# LinearSVR                                                    -7.07
# ExtraTreesRegressor                                          -8.14
# ExtraTreeRegressor                                           -8.74
# DecisionTreeRegressor                                        -8.92
# PassiveAggressiveRegressor                                   -9.39
# GaussianProcessRegressor                                   -103.54
# KernelRidge                                                -147.89
# TransformedTargetRegressor             -31897904657923768844288.00
# LinearRegression                       -31897904657923768844288.00
# RANSACRegressor                     -15511889446600085642149888.00
# Lars                          -33788130306338377063153608425472.00
#
#                                                         R-Squared  \
# Model
# NuSVR                                                        0.29
# RandomForestRegressor                                        0.28
# GammaRegressor                                               0.26
# TweedieRegressor                                             0.26
# KNeighborsRegressor                                          0.25
# BayesianRidge                                                0.25
# SVR                                                          0.25
# ElasticNetCV                                                 0.25
# PoissonRegressor                                             0.24
# LassoCV                                                      0.24
# LassoLarsCV                                                  0.24
# BaggingRegressor                                             0.23
# LassoLarsIC                                                  0.22
# HistGradientBoostingRegressor                                0.21
# OrthogonalMatchingPursuit                                    0.20
# OrthogonalMatchingPursuitCV                                  0.20
# AdaBoostRegressor                                            0.20
# GradientBoostingRegressor                                    0.19
# LGBMRegressor                                                0.19
# LarsCV                                                       0.17
# SGDRegressor                                                 0.16
# RidgeCV                                                      0.15
# XGBRegressor                                                 0.08
# Ridge                                                        0.05
# MLPRegressor                                                 0.01
# HuberRegressor                                               0.01
# LassoLars                                                   -0.00
# ElasticNet                                                  -0.00
# DummyRegressor                                              -0.00
# Lasso                                                       -0.00
# QuantileRegressor                                           -0.00
# LinearSVR                                                   -0.04
# ExtraTreesRegressor                                         -0.17
# ExtraTreeRegressor                                          -0.25
# DecisionTreeRegressor                                       -0.28
# PassiveAggressiveRegressor                                  -0.33
# GaussianProcessRegressor                                   -12.43
# KernelRidge                                                -18.13
# TransformedTargetRegressor             -4098613447666182389760.00
# LinearRegression                       -4098613447666182389760.00
# RANSACRegressor                     -1993147805987720637972480.00
# Lars                          -4341491603607724206961096392704.00
#
#                                              RMSE  Time Taken
# Model
# NuSVR                                        1.26        0.03
# RandomForestRegressor                        1.27        0.54
# GammaRegressor                               1.29        0.01
# TweedieRegressor                             1.29        0.01
# KNeighborsRegressor                          1.29        0.01
# BayesianRidge                                1.30        0.01
# SVR                                          1.30        0.04
# ElasticNetCV                                 1.30        1.72
# PoissonRegressor                             1.30        0.01
# LassoCV                                      1.31        1.48
# LassoLarsCV                                  1.31        0.02
# BaggingRegressor                             1.31        0.07
# LassoLarsIC                                  1.32        0.02
# HistGradientBoostingRegressor                1.33        0.56
# OrthogonalMatchingPursuit                    1.34        0.01
# OrthogonalMatchingPursuitCV                  1.34        0.01
# AdaBoostRegressor                            1.34        0.10
# GradientBoostingRegressor                    1.34        0.22
# LGBMRegressor                                1.35        0.49
# LarsCV                                       1.36        0.09
# SGDRegressor                                 1.37        0.01
# RidgeCV                                      1.38        0.01
# XGBRegressor                                 1.44        0.22
# Ridge                                        1.46        0.01
# MLPRegressor                                 1.49        0.26
# HuberRegressor                               1.49        0.04
# LassoLars                                    1.50        0.01
# ElasticNet                                   1.50        0.01
# DummyRegressor                               1.50        0.00
# Lasso                                        1.50        0.01
# QuantileRegressor                            1.50        0.07
# LinearSVR                                    1.52        0.11
# ExtraTreesRegressor                          1.62        0.75
# ExtraTreeRegressor                           1.68        0.06
# DecisionTreeRegressor                        1.69        0.01
# PassiveAggressiveRegressor                   1.73        0.01
# GaussianProcessRegressor                     5.49        0.05
# KernelRidge                                  6.55        0.01
# TransformedTargetRegressor         95866393176.18        0.01
# LinearRegression                   95866393176.18        0.01
# RANSACRegressor                  2114061711578.00        0.22
# Lars                          3120091931525409.50        0.02

# %% [markdown]
# ## 5. Data visualization of model performance

# %%
# Bar plot of R-squared values
import matplotlib.pyplot as plt
import seaborn as sns

#train["R-Squared'] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize = (5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y = train.index, x = "R-Squared", data = train)
ax.set(xlim = (0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of RMSE values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y = train.index, x = "RMSE", data = train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y = train.index, x = "Time Taken", data=train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
